# %%
from scripts.utils import get_creds

from googleapiclient.discovery import build

# %%
creds = get_creds()
service = build("calendar", "v3", credentials=creds)

# %%
calendarList = (service
                .calendarList()
                .list()
                .execute()
                )

# %%
primaryCalendarId = calendarList["items"][0]
# Out:
# [{'kind': 'calendar#calendarListEntry',
#   'etag': '"1429556005972000"',
#   'id': 'ganael59320@gmail.com',
#   'summary': 'ganael59320@gmail.com',
#   'timeZone': 'Europe/Paris',
#   'colorId': '14',
#   'backgroundColor': '#9fe1e7',
#   'foregroundColor': '#000000',
#   'selected': True,
#   'accessRole': 'owner',
#   'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#   'notificationSettings': {'notifications': [{'type': 'eventCreation',
#      'method': 'email'},
#     {'type': 'eventChange', 'method': 'email'},
#     {'type': 'eventCancellation', 'method': 'email'},
#     {'type': 'eventResponse', 'method': 'email'}]},
#   'primary': True,
#   'conferenceProperties': {'allowedConferenceSolutionTypes': ['hangoutsMeet']}},
#  {'kind': 'calendar#calendarListEntry',
#   'etag': '"1632200499925000"',
#   'id': 'e_2_zh_cn#weeknum@group.v.calendar.google.com',
#   'summary': '周数',
#   'description': '按周显示的周数',
#   'timeZone': 'Europe/Paris',
#   'colorId': '3',
#   'backgroundColor': '#f83a22',
#   'foregroundColor': '#000000',
#   'selected': True,
#   'accessRole': 'reader',
#   'defaultReminders': [],
#   'conferenceProperties': {'allowedConferenceSolutionTypes': ['hangoutsMeet']}},
#  {'kind': 'calendar#calendarListEntry',
#   'etag': '"1632572517381000"',
#   'id': 'addressbook#contacts@group.v.calendar.google.com',
#   'summary': '生日',
#   'description': '显示 Google 通讯录中的联系人的生日、相关周年纪念日以及其他活动日期。',
#   'timeZone': 'Europe/Paris',
#   'colorId': '13',
#   'backgroundColor': '#92e1c0',
#   'foregroundColor': '#000000',
#   'selected': True,
#   'accessRole': 'reader',
#   'defaultReminders': [],
#   'conferenceProperties': {'allowedConferenceSolutionTypes': ['hangoutsMeet']}}]

# %%
primary_calendar = (service
                    .calendars()
                    .get(calendarId="primary")
                    .execute()
                    )

# %%
primary_calendar
# Out:
# {'kind': 'calendar#calendar',
#  'etag': '"hAISC0eqk8mE-PULweYvnvNWgzE"',
#  'id': 'ganael59320@gmail.com',
#  'summary': 'ganael59320@gmail.com',
#  'timeZone': 'Europe/Paris',
#  'conferenceProperties': {'allowedConferenceSolutionTypes': ['hangoutsMeet']}}

# %%
events = service.events().list(calendarId="primary").execute()

# %%
events["items"]
# Out:
# [{'kind': 'calendar#event',
#   'etag': '"3153040920440000"',
#   'id': 'cks3cor56co3ab9i69i68b9kc4r6ab9o6or6ab9h6dh3ccb6coq64d9pcg',
#   'status': 'tentative',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Y2tzM2NvcjU2Y28zYWI5aTY5aTY4YjlrYzRyNmFiOW82b3I2YWI5aDZkaDNjY2I2Y29xNjRkOXBjZyBnYW5hZWw1OTMyMEBt',
#   'created': '2019-12-16T18:21:00.000Z',
#   'updated': '2019-12-16T18:21:00.220Z',
#   'summary': 'Veille Bd Doudou!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2020-04-05'},
#   'end': {'date': '2020-04-06'},
#   'iCalUID': 'cks3cor56co3ab9i69i68b9kc4r6ab9o6or6ab9h6dh3ccb6coq64d9pcg@google.com',
#   'sequence': 1,
#   'reminders': {'useDefault': False},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3192535476108000"',
#   'id': 'ccs3ecb6c4o38b9k69hjab9k68qj4bb16kq62bb56srmacpl6so3adhk74',
#   'status': 'tentative',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Y2NzM2VjYjZjNG8zOGI5azY5aGphYjlrNjhxajRiYjE2a3E2MmJiNTZzcm1hY3BsNnNvM2FkaGs3NCBnYW5hZWw1OTMyMEBt',
#   'created': '2020-08-01T07:42:17.000Z',
#   'updated': '2020-08-01T07:42:18.054Z',
#   'summary': 'Prendre repas Potato rosti!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2020-02-10'},
#   'end': {'date': '2020-02-11'},
#   'iCalUID': 'ccs3ecb6c4o38b9k69hjab9k68qj4bb16kq62bb56srmacpl6so3adhk74@google.com',
#   'sequence': 1,
#   'reminders': {'useDefault': False},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3192535484321000"',
#   'id': 'clgj0db46ph30b9mcdh32b9k6lj36bb16ko30b9i6dh64chk6os3ccb6c8',
#   'status': 'tentative',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Y2xnajBkYjQ2cGgzMGI5bWNkaDMyYjlrNmxqMzZiYjE2a28zMGI5aTZkaDY0Y2hrNm9zM2NjYjZjOCBnYW5hZWw1OTMyMEBt',
#   'created': '2020-08-01T07:42:22.000Z',
#   'updated': '2020-08-01T07:42:22.208Z',
#   'summary': 'Envoi mail à Xueyi ruoyudoudou@gmail.com\n',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2030-05-21'},
#   'end': {'date': '2030-05-22'},
#   'iCalUID': 'clgj0db46ph30b9mcdh32b9k6lj36bb16ko30b9i6dh64chk6os3ccb6c8@google.com',
#   'sequence': 1,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 420}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3192535493744000"',
#   'id': 'chgm2p9kchh3ib9i6him6b9kc9j66b9o71j38b9m71i3ceb66pj36c1pcc',
#   'status': 'tentative',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Y2hnbTJwOWtjaGgzaWI5aTZoaW02YjlrYzlqNjZiOW83MWozOGI5bTcxaTNjZWI2NnBqMzZjMXBjYyBnYW5hZWw1OTMyMEBt',
#   'created': '2020-08-01T07:42:26.000Z',
#   'updated': '2020-08-01T07:42:26.904Z',
#   'summary': 'Envoi mail à Xueyi, ruoyudoudou@gmail.com\nComme dit il y a 10 ans',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2030-05-21'},
#   'end': {'date': '2030-05-22'},
#   'iCalUID': 'chgm2p9kchh3ib9i6him6b9kc9j66b9o71j38b9m71i3ceb66pj36c1pcc@google.com',
#   'sequence': 1,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 420}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3265145034762000"',
#   'id': '_6tlnaqrle5p6cpb4dhmj4phpegq7cq31dgp6usj8d9m6upbeclp6ep3mdhj7csrje1nmgrjkdkr3acbc6pomorr9cdr6qtb6dssm2eb365l30',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=XzZ0bG5hcXJsZTVwNmNwYjRkaG1qNHBocGVncTdjcTMxZGdwNnVzajhkOW02dXBiZWNscDZlcDNtZGhqN2NzcmplMW5tZ3Jqa2RrcjNhY2JjNnBvbW9ycjljZHI2cXRiNmRzc20yZWIzNjVsMzAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2020-10-26T17:35:12.000Z',
#   'updated': '2021-09-25T12:21:57.381Z',
#   'summary': "Stay at Le Roman'Chti",
#   'description': '要查看自动创建的活动（例如这个活动）的详细信息，请使用官方 Google 日历应用。https://g.co/calendar\n\n这项活动是根据您在Gmail中收到的电子邮件建立的。https://mail.google.com/mail?extsrc=cal&plid=ACUX6DMozhtx62P2VOl1a0Ram66BarZngbo_7sg\n',
#   'location': "Le Roman'Chti, Lille",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'unknownorganizer@calendar.google.com'},
#   'start': {'date': '2020-10-29'},
#   'end': {'date': '2020-10-31'},
#   'transparency': 'transparent',
#   'visibility': 'private',
#   'iCalUID': '7kukuqrfedlm2f9t4vhal2orhjloenergdvlfvsspohntm651l6qloicvmufo9a9c1j0',
#   'sequence': 0,
#   'attendees': [{'email': 'ganael59320@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'}],
#   'guestsCanInviteOthers': False,
#   'privateCopy': True,
#   'reminders': {'useDefault': False},
#   'source': {'url': 'https://mail.google.com/mail?extsrc=cal&plid=ACUX6DMozhtx62P2VOl1a0Ram66BarZngbo_7sg',
#    'title': ''},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3265145034762000"',
#   'id': '_6tlnaqrle5p6cpb4dhmj4phpegsmscja6pq36d1hc5lmms31ddnm2qj7dhk72qbd74smcc3ce8q78e32eop7cora6pp6adb5dhij8p9gc5jj0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=XzZ0bG5hcXJsZTVwNmNwYjRkaG1qNHBocGVnc21zY2phNnBxMzZkMWhjNWxtbXMzMWRkbm0ycWo3ZGhrNzJxYmQ3NHNtY2MzY2U4cTc4ZTMyZW9wN2NvcmE2cHA2YWRiNWRoaWo4cDlnYzVqajAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2020-06-14T19:29:18.000Z',
#   'updated': '2021-09-25T12:21:57.381Z',
#   'summary': 'Stay at Studio accès comme hôtel métro Marbrerie Gares/FAC',
#   'description': '要查看自动创建的活动（例如这个活动）的详细信息，请使用官方 Google 日历应用。https://g.co/calendar\n\n这项活动是根据您在Gmail中收到的电子邮件建立的。https://mail.google.com/mail?extsrc=cal&plid=ACUX6DPHbqwjTmYD0V-iiuJC1jdZu9R0KteseVA\n',
#   'location': 'Studio accès comme hôtel métro Marbrerie Gares/FAC, Lille',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'unknownorganizer@calendar.google.com'},
#   'start': {'date': '2020-06-20'},
#   'end': {'date': '2020-06-22'},
#   'transparency': 'transparent',
#   'visibility': 'private',
#   'iCalUID': '7kukuqrfedlm2f9t9n2j6t341akkpakoajglhqim99f0lr4t8bv2vcj6re5ele4e0ag0',
#   'sequence': 0,
#   'attendees': [{'email': 'ganael59320@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'}],
#   'guestsCanInviteOthers': False,
#   'privateCopy': True,
#   'reminders': {'useDefault': False},
#   'source': {'url': 'https://mail.google.com/mail?extsrc=cal&plid=ACUX6DPHbqwjTmYD0V-iiuJC1jdZu9R0KteseVA',
#    'title': ''},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3265145034762000"',
#   'id': '_6tlnaqrle5p6cpb4dhmj4phpehim2qr6dln72pr7d8smkpr1c8q70e1negp6ot3ldos7cc9j60pjis1hdgsmusj8cdgmcdr9ddjmgc9h6cpme',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=XzZ0bG5hcXJsZTVwNmNwYjRkaG1qNHBocGVoaW0ycXI2ZGxuNzJwcjdkOHNta3ByMWM4cTcwZTFuZWdwNm90M2xkb3M3Y2M5ajYwcGppczFoZGdzbXVzajhjZGdtY2RyOWRkam1nYzloNmNwbWUgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2020-07-16T11:27:58.000Z',
#   'updated': '2021-09-25T12:21:57.381Z',
#   'summary': 'Stay at Citadines City Centre Lille (Apart Hotel Lille)',
#   'description': '要查看自动创建的活动（例如这个活动）的详细信息，请使用官方 Google 日历应用。https://g.co/calendar\n\n这项活动是根据您在Gmail中收到的电子邮件建立的。https://mail.google.com/mail?extsrc=cal&plid=ACUX6DMp69BXafxrs0Eb3qw-UFcvOCyQsaLX3zA\n',
#   'location': 'Citadines City Centre Lille (Apart Hotel Lille), Lille',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'unknownorganizer@calendar.google.com'},
#   'start': {'date': '2020-07-18'},
#   'end': {'date': '2020-07-20'},
#   'transparency': 'transparent',
#   'visibility': 'private',
#   'iCalUID': '7kukuqrfedlm2f9teakfmnqggj9jgab4p87t2ltun8v13039p1l9orhcaf7ikgh1133g',
#   'sequence': 0,
#   'attendees': [{'email': 'ganael59320@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'}],
#   'guestsCanInviteOthers': False,
#   'privateCopy': True,
#   'reminders': {'useDefault': False},
#   'source': {'url': 'https://mail.google.com/mail?extsrc=cal&plid=ACUX6DMp69BXafxrs0Eb3qw-UFcvOCyQsaLX3zA',
#    'title': ''},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3265145034762000"',
#   'id': '_6tlnaqrle5p6cpb4dhmj4phpehl32db8epkj4qbld9l3es1ldhh74p1p65h32c9h69k70q37c9j6aqrgepm6mohp68r6athpdhgjgd3bd5j6e',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=XzZ0bG5hcXJsZTVwNmNwYjRkaG1qNHBocGVobDMyZGI4ZXBrajRxYmxkOWwzZXMxbGRoaDc0cDFwNjVoMzJjOWg2OWs3MHEzN2M5ajZhcXJnZXBtNm1vaHA2OHI2YXRocGRoZ2pnZDNiZDVqNmUgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2020-01-30T11:33:17.000Z',
#   'updated': '2021-09-25T12:21:57.381Z',
#   'summary': 'Reservation at Jai-Ho',
#   'description': '要查看自动创建的活动（例如这个活动）的详细信息，请使用官方 Google 日历应用。https://g.co/calendar\n\n这项活动是根据您在Gmail中收到的电子邮件建立的。https://mail.google.com/mail?extsrc=cal&plid=ACUX6DOpbuaaxYb35wv_FmY9QAJhY4WaPqVMxAw\n',
#   'location': '16 Avenue Charles Saint-Venant, 59800 Lille',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'unknownorganizer@calendar.google.com',
#    'displayName': 'Unknown Organizer'},
#   'start': {'dateTime': '2020-01-30T12:30:00+01:00', 'timeZone': 'UTC'},
#   'end': {'dateTime': '2020-01-30T13:30:00+01:00', 'timeZone': 'UTC'},
#   'endTimeUnspecified': True,
#   'transparency': 'transparent',
#   'visibility': 'private',
#   'iCalUID': '7kukuqrfedlm2f9tj15hvi2iujj7p5lbrd91b1112hphgbfekpvlkb926ev9la84kifg',
#   'sequence': 0,
#   'attendees': [{'email': 'ganael59320@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'}],
#   'guestsCanInviteOthers': False,
#   'privateCopy': True,
#   'reminders': {'useDefault': True},
#   'source': {'url': 'https://mail.google.com/mail?extsrc=cal&plid=ACUX6DOpbuaaxYb35wv_FmY9QAJhY4WaPqVMxAw',
#    'title': ''},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3331641395188000"',
#   'id': 'h35gug2n2ai00bcv16h09hmd3s',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=aDM1Z3VnMm4yYWkwMGJjdjE2aDA5aG1kM3MgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2022-10-15T07:58:17.000Z',
#   'updated': '2022-10-15T07:58:17.594Z',
#   'summary': 'Présentation Science Expéludique',
#   'description': 'Ganael D 邀请您参加预先安排的 Zoom 会议。\n\n加入 Zoom 会议\nhttps://us05web.zoom.us/j/84161928438?pwd=b2dHUU5mMFROa3pJRlFNdk9RZXI1Zz09\n\n会议号：841 6192 8438\n密码：uKGC6E\n',
#   'location': 'https://us05web.zoom.us/j/84161928438?pwd=b2dHUU5mMFROa3pJRlFNdk9RZXI1Zz09',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'dateTime': '2022-10-15T10:00:00+02:00',
#    'timeZone': 'Europe/Paris'},
#   'end': {'dateTime': '2022-10-15T10:30:00+02:00', 'timeZone': 'Europe/Paris'},
#   'iCalUID': 'h35gug2n2ai00bcv16h09hmd3s@google.com',
#   'sequence': 0,
#   'extendedProperties': {'shared': {'zmMeetingNum': '84161928438'}},
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3332401101538000"',
#   'id': 'e2ncc18rcnlpmrsf0ngoaa3bd0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZTJuY2MxOHJjbmxwbXJzZjBuZ29hYTNiZDAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2022-10-19T17:29:10.000Z',
#   'updated': '2022-10-19T17:29:10.769Z',
#   'summary': 'Cours mercredi 19/10',
#   'description': 'Ganael D 邀请您参加预先安排的 Zoom 会议。\n\n加入 Zoom 会议\nhttps://us05web.zoom.us/j/81944228967?pwd=ZVJoR3ZDb0VKN0RnWFRIaWI3Mk5yQT09\n\n会议号：819 4422 8967\n密码：6u6CqV\n',
#   'location': 'https://us05web.zoom.us/j/81944228967?pwd=ZVJoR3ZDb0VKN0RnWFRIaWI3Mk5yQT09',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'dateTime': '2022-10-19T20:00:00+02:00',
#    'timeZone': 'Europe/Paris'},
#   'end': {'dateTime': '2022-10-19T20:45:00+02:00', 'timeZone': 'Europe/Paris'},
#   'iCalUID': 'e2ncc18rcnlpmrsf0ngoaa3bd0@google.com',
#   'sequence': 0,
#   'extendedProperties': {'shared': {'zmMeetingNum': '81944228967'}},
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3335969494312000"',
#   'id': '_60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34h9g60s30c1g60o30c1g8oo36h1n6p0j8d9i8opk8e1g64o30c1g60o30c1g60o30c1g60o32c1g60o30c1g6cq3edhj6d242e216crjigpk6gsj8cpj74o3gghj6l336di46sog',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=',
#   'created': '2022-11-09T09:05:25.000Z',
#   'updated': '2022-11-09T09:05:47.156Z',
#   'summary': 'Faisons connaissance / Echange Sopra Steria ',
#   'description': "\n[logo sopra steria]\n[cid:image002.jpg@01D8F352.E928E970]\n[cid:image003.png@01D8F352.E928E970]<https://teams.microsoft.com/l/meetup-join/19%3ameeting_YmZiZjU0M2UtYjBjMi00NmI1LTk5YzEtNjNkOWJhMGEyMDlk%40thread.v2/0?context=%7b%22Tid%22%3a%228b87af7d-8647-4dc7-8df4-5f69a2011bb5%22%2c%22Oid%22%3a%22350e1687-9bcc-45da-8951-67341511d012%22%2c%22IsBroadcastMeeting%22%3atrue%7d>\n\n\nConfirmation d’entretien Teams\n\n\nBonjour Ganaël,\n\nJe vous remercie pour votre disponibilité.\nÀ la suite de nos échanges, je vous confirme notre entretien Teams prévu le :\n\nMercredi 9 novembre 2022 à 10h00.\nVous trouverez l’invitation Teams en fin de mail.\n\nJe reste disponible pour tout complément d’information,\nBien cordialement,\n\n\nJuliette OLCZAK\nChargée de recrutement\n06 42 14 86 37\n[cid:image004.png@01D8F352.E928E970]\n33 Rue Denis Papin\nCS 80390\n59666 Villeneuve d'Ascq Cedex\nPhone: +33 (0)3 28 07 07 07\njuliette.olczak@soprasteria.com<mailto:juliette.olczak@soprasteria.com> - www.soprasteria.fr\nSuivez-nous sur : LinkedIn<https://www.linkedin.com/company/soprasteria>  |  Twitter<https://twitter.com/SopraSteria_fr>  |  Facebook<https://www.facebook.com/soprasteria>\n\nLe contenu de cet e-mail est susceptible d'être confidentiel, soumis au secret professionnel ou protégé par la loi. L'utilisation, la copie et la divulgation non autorisées d'une partie ou de l'intégralité de ce message sont susceptibles d'être illicites. Si vous avez reçu ce message par erreur, supprimez-le après avoir averti l'expéditeur. Les pièces jointes au présent e-mail ont fait l'objet d'un contrôle antivirus. Néanmoins, Sopra Steria Group et ses filiales déclinent toute responsabilité concernant les dommages causés par d'éventuels virus, ainsi que pour tout retard, erreur, altération ou modification affectant la remise ou le contenu du présent email ou de ses pièces jointes.\nPensez à l'environnement avant d'imprimer.\n\nSi vous recevez ce message pendant vos temps non travaillés, il ne requiert ni prise de connaissance, ni réponse immédiate de votre part.\n\n[cid:image005.png@01D8F352.E928E970]\n\n\n\n\n\n\n\n[twitter]<https://twitter.com/SopraSteria_fr>\n[facebook]<https://www.facebook.com/soprasteria/>\n[youtube]<https://www.youtube.com/user/SteriaGroup>\n[linkedin]<https://fr.linkedin.com/company/soprasteria>\n\n\n\n\n\n\n\n________________________________________________________________________________\nRéunion Microsoft Teams\nRejoindre sur votre ordinateur ou application mobile\nCliquez ici pour participer à la réunion<https://teams.microsoft.com/l/meetup-join/19%3ameeting_ZDllNjAxMGQtZmMxMi00ZGFlLWIzODQtNTc2YjAwNjY3OGVi%40thread.v2/0?context=%7b%22Tid%22%3a%228b87af7d-8647-4dc7-8df4-5f69a2011bb5%22%2c%22Oid%22%3a%2255228f3e-5085-4bf8-b9af-f2b44975f70b%22%7d>\nID de réunion : 387 620 277 266\nCode secret : fvBMDU\nTélécharger Teams<https://www.microsoft.com/en-us/microsoft-teams/download-app> | Rejoindre sur le web<https://www.microsoft.com/microsoft-teams/join-a-meeting>\nPour en savoir plus<https://aka.ms/JoinTeamsMeeting> | Options de réunion<https://teams.microsoft.com/meetingOptions/?organizerId=55228f3e-5085-4bf8-b9af-f2b44975f70b&tenantId=8b87af7d-8647-4dc7-8df4-5f69a2011bb5&threadId=19_meeting_ZDllNjAxMGQtZmMxMi00ZGFlLWIzODQtNTc2YjAwNjY3OGVi@thread.v2&messageId=0&language=fr-FR>\n________________________________________________________________________________\n\n",
#   'location': 'Réunion Microsoft Teams',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'juliette.olczak@soprasteria.com',
#    'displayName': 'OLCZAK Juliette'},
#   'start': {'dateTime': '2022-11-09T10:00:00+01:00',
#    'timeZone': 'Africa/Ceuta'},
#   'end': {'dateTime': '2022-11-09T10:30:00+01:00', 'timeZone': 'Africa/Ceuta'},
#   'iCalUID': '040000008200E00074C5B7101A82E00800000000F03D76A452F3D801000000000000000010000000347633DA8A379C449433908B35F36D71',
#   'sequence': 1,
#   'attendees': [{'email': 'ganael.delzenne@gmail.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'ganael59320@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'}],
#   'guestsCanInviteOthers': False,
#   'privateCopy': True,
#   'reminders': {'useDefault': True},
#   'attachments': [{'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.1&disp=attd&zw',
#     'title': 'image001.png',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.2&disp=attd&zw',
#     'title': 'image002.jpg',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.3&disp=attd&zw',
#     'title': 'image003.png',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.4&disp=attd&zw',
#     'title': 'image004.png',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.5&disp=attd&zw',
#     'title': 'image005.png',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.6&disp=attd&zw',
#     'title': 'image006.png',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.7&disp=attd&zw',
#     'title': 'image007.png',
#     'iconLink': ''},
#    {'fileUrl': 'https://mail.google.com/?view=att&th=1845ba336e59891b&attid=0.8&disp=attd&zw',
#     'title': 'image008.png',
#     'iconLink': ''}],
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3367792034298000"',
#   'id': '_cdgmopbechm7ib9n60sjce1m6gsja',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=X2NkZ21vcGJlY2htN2liOW42MHNqY2UxbTZnc2phIGdhbmFlbDU5MzIwQG0',
#   'created': '2023-05-12T12:53:33.000Z',
#   'updated': '2023-05-12T12:53:37.149Z',
#   'summary': 'Réunion de 30 minutes avec Romain Duque',
#   'description': "Nom de l'événement: Réunion de 30 minutes\nDescription de l'événement: \nDate et heure: 10:30 - 11:00 (Heure d'Europe centrale) le mardi, 16 mai 2023\nLieu: Ceci est une conférence en ligne Zoom.\n\nVous pouvez rejoindre cette réunion à partir de votre ordinateur, tablette ou smartphone.\nhttps://us06web.zoom.us/j/83908709123\n\nVous pouvez également le faire depuis votre téléphone.\nUS: +1 305 224 1968, +1 309 205 3325, +1 312 626 6799, +1 646 558 8656, +1 646 931 3860, +1 301 715 8592, +1 360 209 5623, +1 386 347 5053, +1 507 473 4847, +1 564 217 2000, +1 669 444 9171, +16892781000, +1 719 359 4580, +1 720 707 2699, +1 253 205 0468, +1 253 215 8782, +1 346 248 7799\nID de la réunion\xa0: 839-087-09123\n\nTrouvez votre numéro local\xa0: https://us06web.zoom.us/u/kyYU0L6Rd\n\nVeuillez partager tout ce qui pourra être utile à la préparation de notre réunion.: Bonjour, je suis étudiant en école d'ingénieur suivant une formation en informatique. J'ai déjà quelques expériences et souhaiterais en savoir plus sur les possibilités de portage salarial en tant qu'étudiant (ainsi que pour plus tard).\n\nDIDAXIS respecte votre vie privée. Nous n'utilisons vos données personnelles que pour administrer votre compte et vous fournir les produits et services demandés. : J'accepte que DIDAXIS stocke et traite mes données personnelles.\n\nSouhaitez-vous apporter des modifications à cet événement?\nAnnuler: https://calendly.com/cancellations/7c752c08-7e01-4b53-9203-9ba80f9a3965\nReplanifier: https://calendly.com/reschedulings/7c752c08-7e01-4b53-9203-9ba80f9a3965\n",
#   'location': 'https://us06web.zoom.us/j/83908709123',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'noreply@calendly.com',
#    'displayName': 'Romain Duque'},
#   'start': {'dateTime': '2023-05-16T10:30:00+02:00', 'timeZone': 'UTC'},
#   'end': {'dateTime': '2023-05-16T11:00:00+02:00', 'timeZone': 'UTC'},
#   'iCalUID': 'calendly-709686495',
#   'sequence': 0,
#   'attendees': [{'email': 'ganael59320@gmail.com',
#     'self': True,
#     'responseStatus': 'needsAction'}],
#   'guestsCanInviteOthers': False,
#   'privateCopy': True,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594776452000"',
#   'id': '4gc6kjls8vj7lsc7trpqqmckg4',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NGdjNmtqbHM4dmo3bHNjN3RycHFxbWNrZzRfMjAyNDAyMjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:48.000Z',
#   'updated': '2024-03-18T21:29:48.226Z',
#   'description': 'Birthday of Papy',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-02-20'},
#   'end': {'date': '2024-02-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '4gc6kjls8vj7lsc7trpqqmckg4@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594777692000"',
#   'id': '5prhojh2f30grubksu3r36ke5o',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NXByaG9qaDJmMzBncnVia3N1M3IzNmtlNW9fMjAyNDEwMjUgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:49.000Z',
#   'updated': '2024-03-18T21:29:48.846Z',
#   'description': 'Birthday of Xavier',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-10-25'},
#   'end': {'date': '2024-10-26'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '5prhojh2f30grubksu3r36ke5o@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594778946000"',
#   'id': 'fagngiek08sq4dkm517f0lj29o',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZmFnbmdpZWswOHNxNGRrbTUxN2YwbGoyOW9fMjAyNDA5MDcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:49.000Z',
#   'updated': '2024-03-18T21:29:49.473Z',
#   'description': 'Birthday of Greg',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-09-07'},
#   'end': {'date': '2024-09-08'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'fagngiek08sq4dkm517f0lj29o@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594780140000"',
#   'id': 'r4npjnr2ak7ns6snhrnb9ism1c',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cjRucGpucjJhazduczZzbmhybmI5aXNtMWNfMjAyNDExMjcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:50.000Z',
#   'updated': '2024-03-18T21:29:50.070Z',
#   'description': 'Birthday of Mamie',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-27'},
#   'end': {'date': '2024-11-28'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'r4npjnr2ak7ns6snhrnb9ism1c@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594780972000"',
#   'id': '9n88jf5m6206mas77qot475h00',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=OW44OGpmNW02MjA2bWFzNzdxb3Q0NzVoMDBfMjAyNDAzMjIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:50.000Z',
#   'updated': '2024-03-18T21:29:50.486Z',
#   'description': 'Birthday of DorothÃ©e',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-03-22'},
#   'end': {'date': '2024-03-23'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '9n88jf5m6206mas77qot475h00@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594782444000"',
#   'id': 'dnp8hcktfimrieo2dmd6m8duu0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZG5wOGhja3RmaW1yaWVvMmRtZDZtOGR1dTBfMjAyNDA0MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:51.000Z',
#   'updated': '2024-03-18T21:29:51.222Z',
#   'description': 'Birthday of Yvonne',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'dnp8hcktfimrieo2dmd6m8duu0@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594783600000"',
#   'id': 'rp1r5unb0eotc1c3korjc5nqlo',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cnAxcjV1bmIwZW90YzFjM2tvcmpjNW5xbG9fMjAyNDA0MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:52.000Z',
#   'updated': '2024-03-18T21:29:51.800Z',
#   'description': 'Birthday of StÃ©phanie',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'rp1r5unb0eotc1c3korjc5nqlo@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594784852000"',
#   'id': '3om9va165941eggau8qrb87iag',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M29tOXZhMTY1OTQxZWdnYXU4cXJiODdpYWdfMjAyNDExMDEgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:52.000Z',
#   'updated': '2024-03-18T21:29:52.426Z',
#   'description': 'Birthday of Minou',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-01'},
#   'end': {'date': '2024-11-02'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '3om9va165941eggau8qrb87iag@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594785658000"',
#   'id': 'ubmj6e3ufv3eepane794bt2agk',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dWJtajZlM3VmdjNlZXBhbmU3OTRidDJhZ2tfMjAyNDExMTYgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:53.000Z',
#   'updated': '2024-03-18T21:29:52.829Z',
#   'description': 'Birthday of GaÃ«l',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-16'},
#   'end': {'date': '2024-11-17'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'ubmj6e3ufv3eepane794bt2agk@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594786850000"',
#   'id': 'cgq3piq1a8hk5i2thsq694ij88',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Y2dxM3BpcTFhOGhrNWkydGhzcTY5NGlqODhfMjAyNDAxMTMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:53.000Z',
#   'updated': '2024-03-18T21:29:53.425Z',
#   'description': 'Birthday of Marie-ThÃ©rÃ¨se',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-01-13'},
#   'end': {'date': '2024-01-14'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'cgq3piq1a8hk5i2thsq694ij88@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594787698000"',
#   'id': 'lf3vdsl8udb2tcl3o4qtncfmfg',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bGYzdmRzbDh1ZGIydGNsM280cXRuY2ZtZmdfMjAyNDA3MTAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:54.000Z',
#   'updated': '2024-03-18T21:29:53.849Z',
#   'description': 'Birthday of Tistou',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-10'},
#   'end': {'date': '2024-07-11'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'lf3vdsl8udb2tcl3o4qtncfmfg@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594788726000"',
#   'id': '78tvug8n5evb9rj6hl0phcu76k',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Nzh0dnVnOG41ZXZiOXJqNmhsMHBoY3U3NmtfMjAyNDA1MDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:54.000Z',
#   'updated': '2024-03-18T21:29:54.363Z',
#   'description': 'Birthday of Adrien',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-02'},
#   'end': {'date': '2024-05-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '78tvug8n5evb9rj6hl0phcu76k@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594789746000"',
#   'id': '64essigcbiiqj53d23s4tktslg',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NjRlc3NpZ2NiaWlxajUzZDIzczR0a3RzbGdfMjAyNDA2MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:55.000Z',
#   'updated': '2024-03-18T21:29:54.873Z',
#   'description': 'Birthday of Martin',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-20'},
#   'end': {'date': '2024-06-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '64essigcbiiqj53d23s4tktslg@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594790778000"',
#   'id': 'l7rs8dsa3rf113dvqdakqh0f5g',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bDdyczhkc2EzcmYxMTNkdnFkYWtxaDBmNWdfMjAyNDA1MjcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:55.000Z',
#   'updated': '2024-03-18T21:29:55.389Z',
#   'description': 'Birthday of Maxime',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-27'},
#   'end': {'date': '2024-05-28'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'l7rs8dsa3rf113dvqdakqh0f5g@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594792020000"',
#   'id': 'ed7pgbvlo9sgm1q1mdvpp90vo4',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZWQ3cGdidmxvOXNnbTFxMW1kdnBwOTB2bzRfMjAyNDA3MDMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:56.000Z',
#   'updated': '2024-03-18T21:29:56.010Z',
#   'description': 'Birthday of Virginie',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-03'},
#   'end': {'date': '2024-07-04'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'ed7pgbvlo9sgm1q1mdvpp90vo4@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594793056000"',
#   'id': 'nakar0pfc9mi2fdq2u2tmed9pk',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bmFrYXIwcGZjOW1pMmZkcTJ1MnRtZWQ5cGtfMjAyNDExMDggZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:56.000Z',
#   'updated': '2024-03-18T21:29:56.528Z',
#   'description': 'Birthday of Camille',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-08'},
#   'end': {'date': '2024-11-09'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'nakar0pfc9mi2fdq2u2tmed9pk@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594794012000"',
#   'id': 'gt23vdmfaoc2588gkaqu78l1lg',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Z3QyM3ZkbWZhb2MyNTg4Z2thcXU3OGwxbGdfMjAyNDAyMDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:57.000Z',
#   'updated': '2024-03-18T21:29:57.006Z',
#   'description': 'Birthday of Tony',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-02-02'},
#   'end': {'date': '2024-02-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'gt23vdmfaoc2588gkaqu78l1lg@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594795038000"',
#   'id': '4mef515va8sbr568jdl39sik0o',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NG1lZjUxNXZhOHNicjU2OGpkbDM5c2lrMG9fMjAyNDAzMDUgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:57.000Z',
#   'updated': '2024-03-18T21:29:57.519Z',
#   'description': 'Birthday of Corinne',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-03-05'},
#   'end': {'date': '2024-03-06'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': '4mef515va8sbr568jdl39sik0o@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594796354000"',
#   'id': 'jemqj5s8sgr3n1lj6khn0ud954',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=amVtcWo1czhzZ3IzbjFsajZraG4wdWQ5NTRfMjAyNDEyMDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:58.000Z',
#   'updated': '2024-03-18T21:29:58.177Z',
#   'description': 'Birthday of Zhang Lihong',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-12-02'},
#   'end': {'date': '2024-12-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'jemqj5s8sgr3n1lj6khn0ud954@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421594797106000"',
#   'id': 'qmhngberka6u08hnrrudrc07b0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cW1obmdiZXJrYTZ1MDhobnJydWRyYzA3YjBfMjAyNDA2MjEgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:29:58.000Z',
#   'updated': '2024-03-18T21:29:58.553Z',
#   'description': 'Birthday of Dou Mingxuan',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-21'},
#   'end': {'date': '2024-06-22'},
#   'recurrence': ['RRULE:FREQ=YEARLY;COUNT=1'],
#   'iCalUID': 'qmhngberka6u08hnrrudrc07b0@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595247178000"',
#   'id': 'puupgns8u8e978auffcf87ia2k',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cHV1cGduczh1OGU5NzhhdWZmY2Y4N2lhMmtfMjAyNDAyMjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:43.000Z',
#   'updated': '2024-03-18T21:33:43.589Z',
#   'summary': 'Birthday of Papy!',
#   'description': 'Remember to wish Papy a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-02-20'},
#   'end': {'date': '2024-02-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'puupgns8u8e978auffcf87ia2k@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595248316000"',
#   'id': 'oqq5037k11hhnrd2jr1bln2pqo',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=b3FxNTAzN2sxMWhobnJkMmpyMWJsbjJwcW9fMjAyNDEwMjUgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:44.000Z',
#   'updated': '2024-03-18T21:33:44.158Z',
#   'summary': 'Birthday of Xavier!',
#   'description': 'Remember to wish Xavier a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-10-25'},
#   'end': {'date': '2024-10-26'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'oqq5037k11hhnrd2jr1bln2pqo@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595249772000"',
#   'id': 'b7auqcisonqs1j0uinracn0nh8',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=YjdhdXFjaXNvbnFzMWowdWlucmFjbjBuaDhfMjAyNDA5MDcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:45.000Z',
#   'updated': '2024-03-18T21:33:44.886Z',
#   'summary': 'Birthday of Greg!',
#   'description': 'Remember to wish Greg a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-09-07'},
#   'end': {'date': '2024-09-08'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'b7auqcisonqs1j0uinracn0nh8@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595250574000"',
#   'id': '9v7l859l9g0baqckm3hf2cb7f4',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=OXY3bDg1OWw5ZzBiYXFja20zaGYyY2I3ZjRfMjAyNDExMjcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:45.000Z',
#   'updated': '2024-03-18T21:33:45.287Z',
#   'summary': 'Birthday of Mamie!',
#   'description': 'Remember to wish Mamie a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-27'},
#   'end': {'date': '2024-11-28'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '9v7l859l9g0baqckm3hf2cb7f4@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595251794000"',
#   'id': '29gv959jgvq6lqe9h10uv0pd2o',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Mjlndjk1OWpndnE2bHFlOWgxMHV2MHBkMm9fMjAyNDAzMjIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:46.000Z',
#   'updated': '2024-03-18T21:33:45.897Z',
#   'summary': 'Birthday of DorothÃ©e!',
#   'description': 'Remember to wish DorothÃ©e a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-03-22'},
#   'end': {'date': '2024-03-23'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '29gv959jgvq6lqe9h10uv0pd2o@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595253050000"',
#   'id': 'jhbk8hqusckuv31lso5doldtm8',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=amhiazhocXVzY2t1djMxbHNvNWRvbGR0bThfMjAyNDA0MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:46.000Z',
#   'updated': '2024-03-18T21:33:46.525Z',
#   'summary': 'Birthday of Yvonne!',
#   'description': 'Remember to wish Yvonne a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'jhbk8hqusckuv31lso5doldtm8@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595254252000"',
#   'id': '77d40vefg50mc0mdfagherrqi0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NzdkNDB2ZWZnNTBtYzBtZGZhZ2hlcnJxaTBfMjAyNDA0MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:47.000Z',
#   'updated': '2024-03-18T21:33:47.126Z',
#   'summary': 'Birthday of StÃ©phanie!',
#   'description': 'Remember to wish StÃ©phanie a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '77d40vefg50mc0mdfagherrqi0@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595255490000"',
#   'id': 'sbp2dd6qg3qfp29d6n8qij030s',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=c2JwMmRkNnFnM3FmcDI5ZDZuOHFpajAzMHNfMjAyNDExMDEgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:47.000Z',
#   'updated': '2024-03-18T21:33:47.745Z',
#   'summary': 'Birthday of Minou!',
#   'description': 'Remember to wish Minou a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-01'},
#   'end': {'date': '2024-11-02'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'sbp2dd6qg3qfp29d6n8qij030s@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595256640000"',
#   'id': 'c5vvdmg1cm0jsusibf156j6cd8',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=YzV2dmRtZzFjbTBqc3VzaWJmMTU2ajZjZDhfMjAyNDExMTYgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:48.000Z',
#   'updated': '2024-03-18T21:33:48.320Z',
#   'summary': 'Birthday of GaÃ«l!',
#   'description': 'Remember to wish GaÃ«l a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-16'},
#   'end': {'date': '2024-11-17'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'c5vvdmg1cm0jsusibf156j6cd8@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595257738000"',
#   'id': '06d3h55i64ife4bl7k62r86900',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MDZkM2g1NWk2NGlmZTRibDdrNjJyODY5MDBfMjAyNDAxMTMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:49.000Z',
#   'updated': '2024-03-18T21:33:48.869Z',
#   'summary': 'Birthday of Marie-ThÃ©rÃ¨se!',
#   'description': 'Remember to wish Marie-ThÃ©rÃ¨se a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-01-13'},
#   'end': {'date': '2024-01-14'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '06d3h55i64ife4bl7k62r86900@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595258762000"',
#   'id': 'atq6e0fuag84i3edlokrv7rc9c',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=YXRxNmUwZnVhZzg0aTNlZGxva3J2N3JjOWNfMjAyNDA3MTAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:49.000Z',
#   'updated': '2024-03-18T21:33:49.381Z',
#   'summary': 'Birthday of Tistou!',
#   'description': 'Remember to wish Tistou a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-10'},
#   'end': {'date': '2024-07-11'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'atq6e0fuag84i3edlokrv7rc9c@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595259738000"',
#   'id': 'vv6s1ffaef528fe4frtoa5o9h4',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dnY2czFmZmFlZjUyOGZlNGZydG9hNW85aDRfMjAyNDA1MDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:50.000Z',
#   'updated': '2024-03-18T21:33:49.869Z',
#   'summary': 'Birthday of Adrien!',
#   'description': 'Remember to wish Adrien a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-02'},
#   'end': {'date': '2024-05-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'vv6s1ffaef528fe4frtoa5o9h4@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595260636000"',
#   'id': '7uboi4ve7t09d53lpph04vjkig',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3Vib2k0dmU3dDA5ZDUzbHBwaDA0dmpraWdfMjAyNDA2MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:33:50.000Z',
#   'updated': '2024-03-18T21:33:50.318Z',
#   'summary': 'Birthday of Martin!',
#   'description': 'Remember to wish Martin a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-20'},
#   'end': {'date': '2024-06-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '7uboi4ve7t09d53lpph04vjkig@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595261402000"',
#   'id': 'rkmbdtm6oorqai55e7rk9ljad4',
# ...
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595936868000"',
#   'id': '5sen75p107g33eflegntqsnvi8',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NXNlbjc1cDEwN2czM2VmbGVnbnRxc252aThfMjAyNDExMjcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:28.000Z',
#   'updated': '2024-03-18T21:39:28.434Z',
#   'summary': "Birthday of b'Mamie'!",
#   'description': "Remember to wish b'Mamie' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-27'},
#   'end': {'date': '2024-11-28'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '5sen75p107g33eflegntqsnvi8@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595938052000"',
#   'id': 'fvfs5q7ch4bce5bfar9g4qj598',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZnZmczVxN2NoNGJjZTViZmFyOWc0cWo1OThfMjAyNDAzMjIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:29.000Z',
#   'updated': '2024-03-18T21:39:29.026Z',
#   'summary': "Birthday of b'Doroth\\xc3\\x83\\xc2\\xa9e'!",
#   'description': "Remember to wish b'Doroth\\xc3\\x83\\xc2\\xa9e' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-03-22'},
#   'end': {'date': '2024-03-23'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'fvfs5q7ch4bce5bfar9g4qj598@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595938930000"',
#   'id': 'gkefs1bcf3q7jaocjd4ri7sb44',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Z2tlZnMxYmNmM3E3amFvY2pkNHJpN3NiNDRfMjAyNDA0MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:29.000Z',
#   'updated': '2024-03-18T21:39:29.465Z',
#   'summary': "Birthday of b'Yvonne'!",
#   'description': "Remember to wish b'Yvonne' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'gkefs1bcf3q7jaocjd4ri7sb44@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595939882000"',
#   'id': 'mfc2vidk71o7au6fjg4rn6rti8',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bWZjMnZpZGs3MW83YXU2ZmpnNHJuNnJ0aThfMjAyNDA0MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:30.000Z',
#   'updated': '2024-03-18T21:39:29.941Z',
#   'summary': "Birthday of b'St\\xc3\\x83\\xc2\\xa9phanie'!",
#   'description': "Remember to wish b'St\\xc3\\x83\\xc2\\xa9phanie' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'mfc2vidk71o7au6fjg4rn6rti8@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595940780000"',
#   'id': '8vi5qdu6a6erh48f8b5jsg70tc',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=OHZpNXFkdTZhNmVyaDQ4ZjhiNWpzZzcwdGNfMjAyNDExMDEgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:30.000Z',
#   'updated': '2024-03-18T21:39:30.390Z',
#   'summary': "Birthday of b'Minou'!",
#   'description': "Remember to wish b'Minou' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-01'},
#   'end': {'date': '2024-11-02'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '8vi5qdu6a6erh48f8b5jsg70tc@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595941684000"',
#   'id': 'vo170m6a3e2vhphhk40u578860',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dm8xNzBtNmEzZTJ2aHBoaGs0MHU1Nzg4NjBfMjAyNDExMTYgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:31.000Z',
#   'updated': '2024-03-18T21:39:30.842Z',
#   'summary': "Birthday of b'Ga\\xc3\\x83\\xc2\\xabl'!",
#   'description': "Remember to wish b'Ga\\xc3\\x83\\xc2\\xabl' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-16'},
#   'end': {'date': '2024-11-17'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'vo170m6a3e2vhphhk40u578860@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595943004000"',
#   'id': 'l77q5fgb6thloga55entol4ilo',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bDc3cTVmZ2I2dGhsb2dhNTVlbnRvbDRpbG9fMjAyNDAxMTMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:31.000Z',
#   'updated': '2024-03-18T21:39:31.502Z',
#   'summary': "Birthday of b'Marie-Th\\xc3\\x83\\xc2\\xa9r\\xc3\\x83\\xc2\\xa8se'!",
#   'description': "Remember to wish b'Marie-Th\\xc3\\x83\\xc2\\xa9r\\xc3\\x83\\xc2\\xa8se' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-01-13'},
#   'end': {'date': '2024-01-14'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'l77q5fgb6thloga55entol4ilo@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595944274000"',
#   'id': 'afpgkt9h65rm965isidgj49p5k',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=YWZwZ2t0OWg2NXJtOTY1aXNpZGdqNDlwNWtfMjAyNDA3MTAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:32.000Z',
#   'updated': '2024-03-18T21:39:32.137Z',
#   'summary': "Birthday of b'Tistou'!",
#   'description': "Remember to wish b'Tistou' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-10'},
#   'end': {'date': '2024-07-11'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'afpgkt9h65rm965isidgj49p5k@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595945272000"',
#   'id': 'm7go3l3d6ocmugvf1a6qagge18',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bTdnbzNsM2Q2b2NtdWd2ZjFhNnFhZ2dlMThfMjAyNDA1MDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:32.000Z',
#   'updated': '2024-03-18T21:39:32.636Z',
#   'summary': "Birthday of b'Adrien'!",
#   'description': "Remember to wish b'Adrien' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-02'},
#   'end': {'date': '2024-05-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'm7go3l3d6ocmugvf1a6qagge18@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595946542000"',
#   'id': '7ro512jthil44jatmra0kfnvb8',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3JvNTEyanRoaWw0NGphdG1yYTBrZm52YjhfMjAyNDA2MjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:33.000Z',
#   'updated': '2024-03-18T21:39:33.271Z',
#   'summary': "Birthday of b'Martin'!",
#   'description': "Remember to wish b'Martin' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-20'},
#   'end': {'date': '2024-06-21'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '7ro512jthil44jatmra0kfnvb8@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595947408000"',
#   'id': 'kngggdtbb1dnq0ensu24ui7ues',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=a25nZ2dkdGJiMWRucTBlbnN1MjR1aTd1ZXNfMjAyNDA1MjcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:33.000Z',
#   'updated': '2024-03-18T21:39:33.704Z',
#   'summary': "Birthday of b'Maxime'!",
#   'description': "Remember to wish b'Maxime' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-27'},
#   'end': {'date': '2024-05-28'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'kngggdtbb1dnq0ensu24ui7ues@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595948516000"',
#   'id': '04ma60e97pn6r5nicbcm11mmhg',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MDRtYTYwZTk3cG42cjVuaWNiY20xMW1taGdfMjAyNDA3MDMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:34.000Z',
#   'updated': '2024-03-18T21:39:34.258Z',
#   'summary': "Birthday of b'Virginie'!",
#   'description': "Remember to wish b'Virginie' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-03'},
#   'end': {'date': '2024-07-04'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '04ma60e97pn6r5nicbcm11mmhg@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595949336000"',
#   'id': 'hmgr9vm1ij05as8hqh3t04pfho',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=aG1ncjl2bTFpajA1YXM4aHFoM3QwNHBmaG9fMjAyNDExMDggZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:34.000Z',
#   'updated': '2024-03-18T21:39:34.668Z',
#   'summary': "Birthday of b'Camille'!",
#   'description': "Remember to wish b'Camille' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-08'},
#   'end': {'date': '2024-11-09'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'hmgr9vm1ij05as8hqh3t04pfho@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595950710000"',
#   'id': 'r6q73u5h7j59jacji3esndhk7k',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cjZxNzN1NWg3ajU5amFjamkzZXNuZGhrN2tfMjAyNDAyMDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:35.000Z',
#   'updated': '2024-03-18T21:39:35.355Z',
#   'summary': "Birthday of b'Tony'!",
#   'description': "Remember to wish b'Tony' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-02-02'},
#   'end': {'date': '2024-02-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'r6q73u5h7j59jacji3esndhk7k@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595951780000"',
#   'id': '2klt2mfa4igl762qotnlukraqo',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MmtsdDJtZmE0aWdsNzYycW90bmx1a3JhcW9fMjAyNDAzMDUgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:36.000Z',
#   'updated': '2024-03-18T21:39:35.890Z',
#   'summary': "Birthday of b'Corinne'!",
#   'description': "Remember to wish b'Corinne' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-03-05'},
#   'end': {'date': '2024-03-06'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '2klt2mfa4igl762qotnlukraqo@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595952892000"',
#   'id': 'qd3f5hvuram6oqc47jau3404hs',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cWQzZjVodnVyYW02b3FjNDdqYXUzNDA0aHNfMjAyNDEyMDIgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:36.000Z',
#   'updated': '2024-03-18T21:39:36.446Z',
#   'summary': "Birthday of b'Zhang Lihong'!",
#   'description': "Remember to wish b'Zhang Lihong' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-12-02'},
#   'end': {'date': '2024-12-03'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': 'qd3f5hvuram6oqc47jau3404hs@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3421595953862000"',
#   'id': '74qkjndgsl56apv4pfd86g16oo',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NzRxa2puZGdzbDU2YXB2NHBmZDg2ZzE2b29fMjAyNDA2MjEgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-18T21:39:37.000Z',
#   'updated': '2024-03-18T21:39:36.931Z',
#   'summary': "Birthday of b'Dou Mingxuan'!",
#   'description': "Remember to wish b'Dou Mingxuan' a happy birthday!",
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-21'},
#   'end': {'date': '2024-06-22'},
#   'recurrence': ['RRULE:FREQ=YEARLY'],
#   'iCalUID': '74qkjndgsl56apv4pfd86g16oo@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422019447150000"',
#   'id': '65h66chh75h64bb4cgo3gb9k6sp3ibb2ccs34bb56cqj2e9jclj32dhi70',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NjVoNjZjaGg3NWg2NGJiNGNnbzNnYjlrNnNwM2liYjJjY3MzNGJiNTZjcWoyZTlqY2xqMzJkaGk3MCBnYW5hZWw1OTMyMEBt',
#   'created': '2024-03-21T08:28:43.000Z',
#   'updated': '2024-03-21T08:28:43.575Z',
#   'summary': '去买个白萝卜!!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'dateTime': '2024-03-21T17:00:00+01:00',
#    'timeZone': 'Europe/Paris'},
#   'end': {'dateTime': '2024-03-21T21:00:00+01:00', 'timeZone': 'Europe/Paris'},
#   'iCalUID': '65h66chh75h64bb4cgo3gb9k6sp3ibb2ccs34bb56cqj2e9jclj32dhi70@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 60},
#     {'method': 'popup', 'minutes': 5},
#     {'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'}]

# %%
birthdays_to_delete = [event for event in events["items"] if "summary" in event and event["summary"].startswith("Birthday of")]

# %%
birthdays_to_delete = [event for event in events["items"] if "description" in event and event["description"].startswith("Birthday")]

# %%
birthdays_to_delete
# Out:
# [{'kind': 'calendar#event',
#   'etag': '"3422108193606000"',
#   'id': 'krpj86q9c3bejf19lne02v3ibc',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=a3Jwajg2cTljM2JlamYxOWxuZTAydjNpYmMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:16.000Z',
#   'updated': '2024-03-21T20:48:16.803Z',
#   'summary': 'Birthday of Papy!',
#   'description': 'Remember to wish Papy a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2025-02-20'},
#   'end': {'date': '2025-02-21'},
#   'iCalUID': 'krpj86q9c3bejf19lne02v3ibc@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108194818000"',
#   'id': 'g3g93ggjupnskba5arqoitofug',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZzNnOTNnZ2p1cG5za2JhNWFycW9pdG9mdWcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:17.000Z',
#   'updated': '2024-03-21T20:48:17.409Z',
#   'summary': 'Birthday of Xavier!',
#   'description': 'Remember to wish Xavier a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-10-25'},
#   'end': {'date': '2024-10-26'},
#   'iCalUID': 'g3g93ggjupnskba5arqoitofug@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108195650000"',
#   'id': 'a3cor497rsj3kimesfg3h226ds',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=YTNjb3I0OTdyc2oza2ltZXNmZzNoMjI2ZHMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:17.000Z',
#   'updated': '2024-03-21T20:48:17.825Z',
#   'summary': 'Birthday of Greg!',
#   'description': 'Remember to wish Greg a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-09-07'},
#   'end': {'date': '2024-09-08'},
#   'iCalUID': 'a3cor497rsj3kimesfg3h226ds@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108196650000"',
#   'id': '1h3aflkimg39pb0c0nklkvcmtg',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MWgzYWZsa2ltZzM5cGIwYzBua2xrdmNtdGcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:18.000Z',
#   'updated': '2024-03-21T20:48:18.325Z',
#   'summary': 'Birthday of Mamie!',
#   'description': 'Remember to wish Mamie a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-27'},
#   'end': {'date': '2024-11-28'},
#   'iCalUID': '1h3aflkimg39pb0c0nklkvcmtg@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108197686000"',
#   'id': 's74fvailtqbujhdou6cjk32dik',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=czc0ZnZhaWx0cWJ1amhkb3U2Y2prMzJkaWsgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:18.000Z',
#   'updated': '2024-03-21T20:48:18.843Z',
#   'summary': 'Birthday of Dorothée!',
#   'description': 'Remember to wish Dorothée a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-03-22'},
#   'end': {'date': '2024-03-23'},
#   'iCalUID': 's74fvailtqbujhdou6cjk32dik@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108198940000"',
#   'id': '577n4m8u0su7pl8d9epch1ug7o',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NTc3bjRtOHUwc3U3cGw4ZDllcGNoMXVnN28gZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:19.000Z',
#   'updated': '2024-03-21T20:48:19.470Z',
#   'summary': 'Birthday of Yvonne!',
#   'description': 'Remember to wish Yvonne a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'iCalUID': '577n4m8u0su7pl8d9epch1ug7o@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108199794000"',
#   'id': '2arbmf9io9qd6vgihcdt0qncuk',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MmFyYm1mOWlvOXFkNnZnaWhjZHQwcW5jdWsgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:19.000Z',
#   'updated': '2024-03-21T20:48:19.897Z',
#   'summary': 'Birthday of Stéphanie!',
#   'description': 'Remember to wish Stéphanie a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-04-20'},
#   'end': {'date': '2024-04-21'},
#   'iCalUID': '2arbmf9io9qd6vgihcdt0qncuk@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108201378000"',
#   'id': 'mluuf1t2taa5efijl47i4n6l9g',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bWx1dWYxdDJ0YWE1ZWZpamw0N2k0bjZsOWcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:20.000Z',
#   'updated': '2024-03-21T20:48:20.689Z',
#   'summary': 'Birthday of Minou!',
#   'description': 'Remember to wish Minou a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-01'},
#   'end': {'date': '2024-11-02'},
#   'iCalUID': 'mluuf1t2taa5efijl47i4n6l9g@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108202400000"',
#   'id': 'o96r6vqdvup78bcpr0hpu3isdo',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=bzk2cjZ2cWR2dXA3OGJjcHIwaHB1M2lzZG8gZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:21.000Z',
#   'updated': '2024-03-21T20:48:21.200Z',
#   'summary': 'Birthday of Gaël!',
#   'description': 'Remember to wish Gaël a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-16'},
#   'end': {'date': '2024-11-17'},
#   'iCalUID': 'o96r6vqdvup78bcpr0hpu3isdo@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108203648000"',
#   'id': '3ef3bq56rkuj73r6460d4nms1c',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2VmM2JxNTZya3VqNzNyNjQ2MGQ0bm1zMWMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:21.000Z',
#   'updated': '2024-03-21T20:48:21.824Z',
#   'summary': 'Birthday of Marie-Thérèse!',
#   'description': 'Remember to wish Marie-Thérèse a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2025-01-13'},
#   'end': {'date': '2025-01-14'},
#   'iCalUID': '3ef3bq56rkuj73r6460d4nms1c@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108204666000"',
#   'id': 'd0gadcnp1uisdtehdpljntt04c',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZDBnYWRjbnAxdWlzZHRlaGRwbGpudHQwNGMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:22.000Z',
#   'updated': '2024-03-21T20:48:22.333Z',
#   'summary': 'Birthday of Tistou!',
#   'description': 'Remember to wish Tistou a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-10'},
#   'end': {'date': '2024-07-11'},
#   'iCalUID': 'd0gadcnp1uisdtehdpljntt04c@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108205290000"',
#   'id': 'rli7dbn775moccer5qojuh5nas',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cmxpN2Ribjc3NW1vY2NlcjVxb2p1aDVuYXMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:22.000Z',
#   'updated': '2024-03-21T20:48:22.645Z',
#   'summary': 'Birthday of Adrien!',
#   'description': 'Remember to wish Adrien a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-02'},
#   'end': {'date': '2024-05-03'},
#   'iCalUID': 'rli7dbn775moccer5qojuh5nas@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108206118000"',
#   'id': 'u7s49h8gkp5c0p9ueuis2j29vc',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dTdzNDloOGdrcDVjMHA5dWV1aXMyajI5dmMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:23.000Z',
#   'updated': '2024-03-21T20:48:23.059Z',
#   'summary': 'Birthday of Martin!',
#   'description': 'Remember to wish Martin a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-20'},
#   'end': {'date': '2024-06-21'},
#   'iCalUID': 'u7s49h8gkp5c0p9ueuis2j29vc@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108207294000"',
#   'id': 'd4th7euus97tioaj4uekrjbr3s',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZDR0aDdldXVzOTd0aW9hajR1ZWtyamJyM3MgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:23.000Z',
#   'updated': '2024-03-21T20:48:23.647Z',
#   'summary': 'Birthday of Maxime!',
#   'description': 'Remember to wish Maxime a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-05-27'},
#   'end': {'date': '2024-05-28'},
#   'iCalUID': 'd4th7euus97tioaj4uekrjbr3s@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108208108000"',
#   'id': 'qtrtopc72hfqrnlp52er99ekf0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=cXRydG9wYzcyaGZxcm5scDUyZXI5OWVrZjAgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:24.000Z',
#   'updated': '2024-03-21T20:48:24.054Z',
#   'summary': 'Birthday of Virginie!',
#   'description': 'Remember to wish Virginie a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-07-03'},
#   'end': {'date': '2024-07-04'},
#   'iCalUID': 'qtrtopc72hfqrnlp52er99ekf0@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108209372000"',
#   'id': 'uc48bt3g0pe01igt5fpnkdai48',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dWM0OGJ0M2cwcGUwMWlndDVmcG5rZGFpNDggZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:24.000Z',
#   'updated': '2024-03-21T20:48:24.686Z',
#   'summary': 'Birthday of Camille!',
#   'description': 'Remember to wish Camille a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-11-08'},
#   'end': {'date': '2024-11-09'},
#   'iCalUID': 'uc48bt3g0pe01igt5fpnkdai48@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108210402000"',
#   'id': 'gtus98tfb5sot5b2eef3tm9tmg',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Z3R1czk4dGZiNXNvdDViMmVlZjN0bTl0bWcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:25.000Z',
#   'updated': '2024-03-21T20:48:25.201Z',
#   'summary': 'Birthday of Tony!',
#   'description': 'Remember to wish Tony a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2025-02-02'},
#   'end': {'date': '2025-02-03'},
#   'iCalUID': 'gtus98tfb5sot5b2eef3tm9tmg@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108211850000"',
#   'id': 'jvrh428jt97qjt2ou45tuv49kc',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=anZyaDQyOGp0OTdxanQyb3U0NXR1djQ5a2MgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:25.000Z',
#   'updated': '2024-03-21T20:48:25.925Z',
#   'summary': 'Birthday of Corinne!',
#   'description': 'Remember to wish Corinne a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2025-03-05'},
#   'end': {'date': '2025-03-06'},
#   'iCalUID': 'jvrh428jt97qjt2ou45tuv49kc@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108212808000"',
#   'id': 'ur5bfoj4vk9dksjqaqspie216g',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dXI1YmZvajR2azlka3NqcWFxc3BpZTIxNmcgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:26.000Z',
#   'updated': '2024-03-21T20:48:26.404Z',
#   'summary': 'Birthday of Zhang Lihong!',
#   'description': 'Remember to wish Zhang Lihong a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-12-02'},
#   'end': {'date': '2024-12-03'},
#   'iCalUID': 'ur5bfoj4vk9dksjqaqspie216g@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3422108213898000"',
#   'id': '0a4i0bcdot5oombrnehorj1hnc',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MGE0aTBiY2RvdDVvb21icm5laG9yajFobmMgZ2FuYWVsNTkzMjBAbQ',
#   'created': '2024-03-21T20:48:26.000Z',
#   'updated': '2024-03-21T20:48:26.949Z',
#   'summary': 'Birthday of Dou Mingxuan!',
#   'description': 'Remember to wish Dou Mingxuan a happy birthday!',
#   'creator': {'email': 'ganael59320@gmail.com', 'self': True},
#   'organizer': {'email': 'ganael59320@gmail.com', 'self': True},
#   'start': {'date': '2024-06-21'},
#   'end': {'date': '2024-06-22'},
#   'iCalUID': '0a4i0bcdot5oombrnehorj1hnc@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 30}]},
#   'eventType': 'default'}]

# %%
from tqdm import tqdm

for birthday in tqdm(birthdays_to_delete):
    delete_result = service.events().delete(calendarId="primary", eventId=birthday["id"]).execute()
# Out:
# 100%|██████████| 20/20 [00:10<00:00,  1.97it/s]
